# %%
products = ["tshirt", "mug", "hat", "book", "keychain"]
inventory = {}
customer_orders = set()
order_status = ()

#P=Prodcut

P1=int(input("Please enter the no. of tshirts: "))
P2=int(input("Please enter the no. of mugs: "))
P3=int(input("Please enter the no. of hats: "))
P4=int(input("Please enter the no. of books: "))
P5=int(input("Please enter the no. of keychains: "))
inventory[products[0]]=P1
inventory[products[1]]=P2
inventory[products[2]]=P3
inventory[products[3]]=P4
inventory[products[4]]=P5


print("Please enter then name of three products that the customer wants to order")
#CP=Customer Product
CP1= input(("Please enther product no.1: "))
CP2= input(("Please enther product no.2: "))
CP3= input(("Please enther product no.3: "))
customer_orders.add(CP1)
customer_orders.add(CP2)
customer_orders.add(CP3)


#TO = Total orders
#AP = Available products
#PP = Prodcut percentage ordered
TO = len(customer_orders)
AP = len(products)
PP = (TO/AP)*100
order_status = (TO, AP, PP)
#print(order_status)
print(f"Total no. of products ordered are: {TO}")
print(f"Percentage of products ordere is: {PP}")


for i in customer_orders:
        inventory[i]=inventory[i]-1
print (inventory)
# Out:
# Please enter the no. of tshirts:  50
# Please enter the no. of mugs:  50
# Please enter the no. of hats:  50
# Please enter the no. of books:  50
# Please enter the no. of keychains:  50
# Please enter then name of three products that the customer wants to order
# Please enther product no.1:  tshirt
# Please enther product no.2:  mug
# Please enther product no.3:  book
# Total no. of products ordered are: 3
# Percentage of products ordere is: 60.0
# {'tshirt': 49, 'mug': 49, 'hat': 50, 'book': 49, 'keychain': 50}
